# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd 

from statsmodels.tsa.seasonal import seasonal_decompose
plt.style.use('grayscale')

# %%
df  = pd.read_csv('AirPassengers.csv')

# %%
df.sample(2)
# Out:
#        Month  #Passengers
# 100  1957-05          355
# 51   1953-04          235

# %%
df.dtypes
# Out:
# Month          object
# #Passengers     int64
# dtype: object

# %% [raw]
# STEP-1
#
# if we want to do time series analysis we will convert Month column into time

# %%
# Month columns change into time
df = pd.read_csv('AirPassengers.csv',parse_dates=['Month'])
# we changed our data into (year-month-day) format coz, our Month column have data look data

# %%
df.dtypes # column chnaged sucsssfully
# Out:
# Month          datetime64[ns]
# #Passengers             int64
# dtype: object

# %%
df.head()
# Out:
#        Month  #Passengers
# 0 1949-01-01          112
# 1 1949-02-01          118
# 2 1949-03-01          132
# 3 1949-04-01          129
# 4 1949-05-01          121

# %% [raw]
# STEP-2
#
# we have to convert TIME column (which is MONTH) as INDEX column

# %%
df = pd.read_csv('AirPassengers.csv',parse_dates=['Month'],index_col=['Month'])

# %%
df.sample(4)
# Out:
#             #Passengers
# Month
# 1949-11-01          104
# 1954-08-01          293
# 1957-08-01          467
# 1957-11-01          305

# %%
df['1951-03-01':'1951-07-01']
# Out:
#             #Passengers
# Month
# 1951-03-01          178
# 1951-04-01          163
# 1951-05-01          172
# 1951-06-01          178
# 1951-07-01          199

# %%
df.loc['1960-05-01']
# Out:
# #Passengers    472
# Name: 1960-05-01 00:00:00, dtype: int64

# %%
df.plot()
plt.title('In here upward trend')
plt.show()

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 16,8

# %%
df.plot()
plt.title('In here upward trend')
plt.show()

# %% [raw]
# In Above figure we clearly see our SEASONAL component is NOT CONSTANT
# so, we will use MULTIPLICATIVE Model
#
# # compare:
#     A).   1950 to 1951 graph is not contant with 1959 to 1960
#     B).   it have much more upward trend
#     c).   so, we will use MULTIPLICATIVE Model

# %%
# Decompose the time series MULTIPLICATIVE
df_multiplicative_decompose = seasonal_decompose(df,model='multiplicative')
df_multiplicative_decompose.plot()
plt.show()
